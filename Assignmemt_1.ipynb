# %% [markdown]
# # **Assignment 01**

# %%
#1. Simple ATM Calculator
balance_amt = 5000
withdraw_amt = 1500
sufficient_balance = 500
if balance_amt > withdraw_amt:
  balance_amt-= withdraw_amt
  print(f'Transaction successful. Remaining balance: {balance_amt}')
else:
  print(f'No sufficient balance in your account')
# Out:
# Transaction successful. Remaining balance: 3500

# %%
#2. Electricity Bill Generator
unit_consumed = int(input('Enter Units consumed: '))
bill =0

if unit_consumed <= 100: #Units less than or equal to 100
  bill= unit_consumed*5
elif unit_consumed<=200: #Units between 101 and 200
  bill = (100 *5)+((unit_consumed-100)*7)
else:
  bill= (100*5)+(100*7)+((unit_consumed-200)*10)

print("Bill amount = ₹", bill)
# Out:
# Enter Units consumed:  10
# Bill amount = ₹ 50

# %%
#3. Temperature Converter

temp = float(input('Enter your temperature: '))
while True:

  unit=input('Enter unit (C/F): ')
  if unit=="C":
    fah = (temp*9/5)+32
    print(f'Temperature in Fahrenheit: {fah:.2f} ℉')
    break
  elif unit=='F':
    cel =(temp-32)*5/9
    print(f'Temperature in Celsius:{cel:.2f} ℃')
    break
  else:
    print(input('Invalid unit! Please enter C or F.'))
# Out:
# Enter your temperature:  36
# Enter unit (C/F):  F
# Temperature in Celsius:2.22 ℃

# %%
#4. Mobile Recharge Validity
from datetime import datetime, timedelta
today = datetime.strptime('2025-08-26','%Y-%m-%d')
Recharge_date= datetime.strptime('2025-09-01','%Y-%m-%d')
exp_date = Recharge_date+timedelta(days=28)
if today <= exp_date:
  print(f'Enjoy your recharge until {exp_date.date()}')
else:
  print('Plan expired. Recharge again. ')
# Out:
# Enjoy your recharge until 2025-09-29

# %%
#5. Bus Seat Reservation System:
Booked = ['Amit', 'Sara', 'John','sanju','aswin','sahil','selin']
Cancel = 'Sara'
New = 'Neha'
Position = 1
# Remove cancelled passenger
if Cancel in Booked:
  Booked.remove(Cancel)
# Insert new passenger
Booked.insert(Position, New)
print(Booked)
# Out:
# ['Amit', 'Neha', 'John', 'sanju', 'aswin', 'sahil', 'selin']

# %%
#6. Sum of even numbers
total =0
num=int(input('Enter a number: '))

for i in range(1,num+1):
   if i%2 == 0:
    total+=i
print('Sum of even numbers:', total)
# Out:
# Enter a number: 10
# Sum of even numbers: 30

# %%
#7. Dictionary – Student Marks Summary
students ={}
for i in range(3):
  name =input('Enter name: ')
  marks = int(input('Enter marks: '))
  students[name]=marks
avg = sum(students.values())/len(students)
print('Average Marks: ',avg)
# Out:
# Enter name:  sanju
# Enter marks:  100
# Enter name:  aswanth
# Enter marks:  98
# Enter name:  aravind
# Enter marks:  95
# Average Marks:  97.66666666666667

# %%
#8. Dictionary – Word Frequency

text= input('enter text: ')

#print(text.lower().split())
word_count = {}
for word in text.lower().split():
  if word in word_count:
    word_count[word]+=1
  else:
    word_count[word]=1
print('word counts are: ',word_count)
# Out:
# enter text:  Arthur spent forty years fixing other people’s time. His shop was a dark, quiet cave filled with the ticking of a hundred brass hearts. Pendulums swung like lazy pendulums; gears turned in tiny, oiled circles.On a rainy Tuesday, an old man in a heavy coat brought in a pocket watch made of dark, heavy metal that Arthur did not recognize. It had no numbers on its face, only a single silver hand pointing straight up at a tiny engraving of a keyhole."It does not tell the hours," the stranger whispered, laying it on the glass counter. "It measures what is left.""Left of what?" Arthur asked, reaching for his jeweler’s loupe."Your own stillness," the old man said, and walked out before Arthur could give him a receipt.
# ...

# %%
#8. Functions – Check Prime
prime =int(input('enter a number: '))
if prime/prime==0 or prime/1 ==0:
  print(f'{prime} is a prime number')
else:
  print(f'{prime} is not a prime number')
# Out:
# enter a number:  28
# 28 is not a prime number

# %%
#9. Vowel Counter
user_vowel = input('enter a string: ')
num_vowel =0
vowels =['a','e','i','o','u']
for char in user_vowel.lower():
  if char in vowels:
   num_vowel+=1
print(f'Number of vowels: {num_vowel} ')
# Out:
# enter a string:  hi everybody
# Number of vowels: 4

# %%
#10. Count Divisible Numbers
N = int(input('Enter range limit: '))
D = int(input('Enter divisor: '))
count=0
for i in range(1,N+1):
  if i%D==0:
    count+=1
print(f'count of numbers divisible by {D}: {count} ')
# Out:
# Enter range limit: 500
# Enter divisor: 4
# count of numbers divisible by 4: 125
